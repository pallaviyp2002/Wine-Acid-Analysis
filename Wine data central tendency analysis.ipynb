# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv("Wine Quality Dataset.csv")

# %%
df
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.0              0.27         0.36            20.7      0.045
# 1               6.3              0.30         0.34             1.6      0.049
# 2               8.1              0.28         0.40             6.9      0.050
# 3               7.2              0.23         0.32             8.5      0.058
# 4               7.2              0.23         0.32             8.5      0.058
# ...             ...               ...          ...             ...        ...
# 4893            6.2              0.21         0.29             1.6      0.039
# 4894            6.6              0.32         0.36             8.0      0.047
# 4895            6.5              0.24         0.19             1.2      0.041
# 4896            5.5              0.29         0.30             1.1      0.022
# 4897            6.0              0.21         0.38             0.8      0.020
#
# ...

# %%
df.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.0              0.27         0.36            20.7      0.045
# 1            6.3              0.30         0.34             1.6      0.049
# 2            8.1              0.28         0.40             6.9      0.050
# 3            7.2              0.23         0.32             8.5      0.058
# 4            7.2              0.23         0.32             8.5      0.058
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 45.0                 170.0   1.0010  3.00       0.45
# 1                 14.0                 132.0   0.9940  3.30       0.49
# 2                 30.0                  97.0   0.9951  3.26       0.44
# 3                 47.0                 186.0   0.9956  3.19       0.40
# 4                 47.0                 186.0   0.9956  3.19       0.40
#
#    alcohol  quality
# 0      8.8        6
# 1      9.5        6
# 2     10.1        6
# ...

# %%
df.shape
# Out:
# (4898, 12)

# %%
df.index
# Out:
# RangeIndex(start=0, stop=4898, step=1)

# %%
df.columns
# Out:
# Index(['fixed acidity', 'volatile acidity', 'citric acid', 'residual sugar',
#        'chlorides', 'free sulfur dioxide', 'total sulfur dioxide', 'density',
#        'pH', 'sulphates', 'alcohol', 'quality'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4898 entries, 0 to 4897
# Data columns (total 12 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   fixed acidity         4898 non-null   float64
#  1   volatile acidity      4898 non-null   float64
#  2   citric acid           4898 non-null   float64
#  3   residual sugar        4898 non-null   float64
#  4   chlorides             4898 non-null   float64
#  5   free sulfur dioxide   4898 non-null   float64
#  6   total sulfur dioxide  4898 non-null   float64
#  7   density               4898 non-null   float64
#  8   pH                    4898 non-null   float64
#  9   sulphates             4898 non-null   float64
#  10  alcohol               4898 non-null   float64
#  11  quality               4898 non-null   int64
# dtypes: float64(11), int64(1)
# memory usage: 459.3 KB

# %%
plt.figure(figsize = (10,10))

# %%
sns.histplot(data=df,color="pink",x="fixed acidity",edgecolor ="purple",bins = 5)
plt.title("Histogram of fixed acidity")
plt.xlabel("fixed acidity")
plt.ylabel("count")
plt.show()
# Out:
# C:\Users\Pallavi Y P\anaconda3\jupi\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
round(df["fixed acidity"].mean())
# Out:
# 7

# %%
df["fixed acidity"].median()
# Out:
# 6.8

# %%
plt.figure(figsize = (10,10))
sns.histplot(data=df,x="fixed acidity",color="red",edgecolor="blue",bins=5)
plt.title("Histogram of fixed acidity")
plt.xlabel("fixed acidity")
plt.ylabel("count")
plt.vlines(df["fixed acidity"].mean(),ymin=0,ymax=4000,color="black",label="mean")
plt.vlines(df["fixed acidity"].median(),ymin=0,ymax=4000,color="orange",label="median")
plt.show()
# Out:
# C:\Users\Pallavi Y P\anaconda3\jupi\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %% [markdown]
# # from the above histogram figure fixed acidity as mean of 7

# %%
 df["volatile acidity"]
# Out:
# 0       0.27
# 1       0.30
# 2       0.28
# 3       0.23
# 4       0.23
#         ...
# 4893    0.21
# 4894    0.32
# 4895    0.24
# 4896    0.29
# 4897    0.21
# Name: volatile acidity, Length: 4898, dtype: float64

# %%
plt.figure(figsize=(10,5))
sns.histplot(data=df,x="volatile acidity",color = "blue",edgecolor = "pink",bins = 5)
plt.title("Histogram of volatile acidity")
plt.xlabel("volatile acidity")
plt.ylabel("counts")
plt.show()
# Out:
# C:\Users\Pallavi Y P\anaconda3\jupi\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %% [markdown]
# # this histogram is positively skewed (asymmetric), hence we need to plot normal distplot

# %%
plt.figure(figsize=(10,5))
sns.distplot(df["volatile acidity"],color = "orange")
plt.title("Normal distribution of volatile acidity")
plt.xlabel("volatile acidity")
plt.ylabel("counts")
plt.show()
# Out:
# C:\Users\Pallavi Y P\AppData\Local\Temp\ipykernel_8076\1058075790.py:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df["volatile acidity"],color = "orange")
# C:\Users\Pallavi Y P\anaconda3\jupi\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %% [markdown]
# #  Normal distribution of volatile acidity
# It has mean and median are same
# It has only mode
# It is positively skewed curve

# %%
df["volatile acidity"].skew()
# Out:
# 1.5769795029952025

# %% [markdown]
# # It is more than one hence it is positively skewed

# %%
df["volatile acidity"].mean()
# Out:
# 0.27824111882400976

# %%
df["volatile acidity"].median()
# Out:
# 0.26

# %% [markdown]
# # by the observation we say that both mean and median are equal

# %%
plt.figure(figsize = (10,5))
sns.histplot(data=df,x="volatile acidity",color="red",edgecolor="blue",bins=5)
plt.title("Histogram of volatile acidity")
plt.xlabel("volatile acidity")
plt.ylabel("count")
plt.vlines(df["volatile acidity"].mean(),ymin=0,ymax=4000,color="black",label="mean")
plt.vlines(df["volatile acidity"].median(),ymin=0,ymax=4000,color="orange",label="median")
plt.show()
# Out:
# C:\Users\Pallavi Y P\anaconda3\jupi\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
plt.figure(figsize=(10,5))
sns.histplot(data=df,x="citric acid",color = "purple",edgecolor = "pink",bins = 5)
plt.title("Histogram of citric acid")
plt.xlabel("citric acid")
plt.ylabel("counts")
plt.show()
# Out:
# C:\Users\Pallavi Y P\anaconda3\jupi\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
df["citric acid"].mean()
# Out:
# 0.33419150673744386

# %%
df["citric acid"].median()
# Out:
# 0.32

# %% [markdown]
# # By the observation we say that citric acid has equal mean and median

# %%
plt.figure(figsize=(10,5))
sns.distplot(df["citric acid"],color = "yellow")
plt.title("Normal distribution of citric acid")
plt.xlabel("citric acid")
plt.ylabel("counts")
plt.show()
# Out:
# C:\Users\Pallavi Y P\AppData\Local\Temp\ipykernel_8076\2160705938.py:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df["citric acid"],color = "yellow")
# C:\Users\Pallavi Y P\anaconda3\jupi\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
plt.figure(figsize=(11,6))
sns.countplot(df['quality'])
plt.title("Count of quality")
plt.xlabel("quality")
plt.ylabel("counts")
plt.show()

# %%
df["quality"].value_counts().index[0]
# Out:
# 6

# %%
rep_acid = pd.Series(index = ["fixed acidity","volatile acidity","citrc acid"],
                     data=[df["fixed acidity"].mean(),df["volatile acidity"].mean(),df["citric acid"].mean])

# %% [raw]
# rep_acid
